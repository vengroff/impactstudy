# %% [markdown]
# # Linear Target; Correlated with Confound

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import impactstudy.experiment as ise

# %% [markdown]
# ## Configuration

# %%
N = 250

# %%
M = 1

# %%
S = 1

# %%
M2 = 1

# %%
S2 = 1

# %%
SIGMA = 10.0

# %%
CORRS = [0.5, 0.6, 0.7, 0.8, 0.9, 0.95, 0.99]

# %% [markdown]
# ## A Single Scenario For Manual Verification.
#
# ### Set Up the Scenario

# %%
experiment0 = ise.CorrelatedLinearWithNoiseExperiment(
    m=M, s=S, sigma=SIGMA, corr=CORRS[-1], n=N, m2=M2, s2=S2
)

# %% [markdown]
# ### Generate Impact Charts

# %%
tags, scenario = next(experiment0.scenarios())

# %%
impact_charts = scenario.model_impact_charts(linreg_overlay=True)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits

# %% [markdown]
# ### Generate Metrics

# %%
scenario.model_errors(linreg_errors=True)
# Out:
#       metric       x_0       x_1       c_0       c_1    mu_x_i    mu_c_i
# 0       RMSE  6.854214  3.126064  4.338398  0.664515  4.990139  2.501456
# 0        MAE  4.396230  1.968378  3.588563  0.531158  3.182304  2.059860
# 0     MED_AE  2.597193  1.373866  3.351764  0.503827  1.985530  1.927796
# 0    LR_RMSE  0.041184  0.580490  0.524815  0.881096  0.310837  0.702955
# 0     LR_MAE  0.031945  0.445518  0.407317  0.696216  0.238732  0.551766
# 0  LR_MED_AE  0.027356  0.342176  0.323367  0.564385  0.184766  0.443876

# %%
scenario.linreg_r2(), scenario.model_r2()
# Out:
# (0.8776088481604625, 0.8981899150238435)

# %% [markdown]
# ## A Multi-Scenario Experiment

# %%
experiment = ise.CorrelatedLinearWithNoiseExperiment(
    m=M, s=S, sigma=SIGMA, corr=CORRS, n=N, m2=M2, s2=S2
)

# %%
df_model_errors = experiment.model_errors(linreg_errors=True)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits

# %%
df_model_errors
# Out:
#       metric       x_0       x_1       c_0       c_1    mu_x_i    mu_c_i  m  \
# 0       RMSE  4.655333  3.377868  0.714195  0.810541  4.016601  0.762368  1
# 0        MAE  2.298914  2.182138  0.479143  0.657374  2.240526  0.568259  1
# 0     MED_AE  1.570576  1.520603  0.316438  0.620383  1.545590  0.468411  1
# 0    LR_RMSE  0.283786  0.580490  0.372598  0.881096  0.432138  0.626847  1
# 0     LR_MAE  0.222831  0.445518  0.297031  0.696216  0.334175  0.496623  1
# 0  LR_MED_AE  0.187669  0.342176  0.248171  0.564385  0.264922  0.406278  1
# 0       RMSE  4.690665  3.290431  0.829235  0.690699  3.990548  0.759967  1
# 0        MAE  2.380229  2.063864  0.582988  0.563856  2.222047  0.573422  1
# 0     MED_AE  1.606034  1.385046  0.424847  0.537496  1.495540  0.481171  1
# 0    LR_RMSE  0.269991  0.580490  0.364655  0.881096  0.425240  0.622875  1
# 0     LR_MAE  0.212269  0.445518  0.289557  0.696216  0.328894  0.492886  1
# ...

# %%
ax = experiment.plot_model_errors(x_col="corr", y_col="mu_x_i", figsize=(6, 4))

# %%
ax = experiment.plot_r2(x_col="corr", figsize=(6, 4))

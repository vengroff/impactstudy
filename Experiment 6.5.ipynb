# %% [markdown]
# # Sinusoidal Target; Variable Number of Sinusoidal Terms
#
# Uniformly distributed $x_i$.
#
# $$
# \begin{align}
# f(X) & = A \cdot X[0, m_1) + b + \left(\sum_{i = m_1}^{m_1 + m_2} {\beta_i} + {\alpha_i}_{\chi[t_i, \infty)}(X[i]) \right); \\
# m_2 & = 4; \\
# m_1 & \ge 1; \\
# s & = 5; \\
# Z & = N(0, \sigma^2).
# \end{align}
# $$

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import impactstudy.experiment as ise

# %% [markdown]
# ## Configuration

# %%
N = 250

# %%
M = list(range(2, 17, 2))

# %%
S = 0

# %%
SIGMA = 20.0

# %% [markdown]
# ## A Single Scenario For Manual Verification.
#
# ### Set Up the Scenario

# %%
experiment0 = ise.SinusoidalWithNoiseExperiment(m=M[0], s=S, sigma=SIGMA)

# %% [markdown]
# ### Generate Impact Charts

# %%
tags, scenario = next(experiment0.scenarios())

# %%
impact_charts = scenario.model_impact_charts(N, linreg_overlay=True)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits

# %% [markdown]
# ### Generate Metrics

# %%
scenario.model_errors(N, linreg_errors=True)
# Out:
#       metric        x_0        x_1     mu_x_i
# 0       RMSE   9.045446   9.221843   9.133644
# 0        MAE   7.398497   7.648028   7.523263
# 0     MED_AE   6.974810   7.154925   7.064868
# 0    LR_RMSE  47.479163  47.436565  47.457864
# 0     LR_MAE  42.638861  41.694531  42.166696
# 0  LR_MED_AE  45.520869  44.112606  44.816737

# %%
scenario.linreg_r2(N), scenario.model_r2(N)
# Out:
# (0.05791375088525885, 0.946462300263742)

# %% [markdown]
# ## A Multi-Scenario Experiment

# %%
experiment = ise.SinusoidalWithNoiseExperiment(m=M, s=S, sigma=SIGMA)

# %%
experiment.model_errors(N, linreg_errors=True)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
#       metric        x_0        x_1     mu_x_i   m  s  sigma     IM_R2  \
# 0       RMSE   9.045446   9.221843   9.133644   2  0   20.0  0.946462
# 0        MAE   7.398497   7.648028   7.523263   2  0   20.0  0.946462
# 0     MED_AE   6.974810   7.154925   7.064868   2  0   20.0  0.946462
# 0    LR_RMSE  47.479163  47.436565  47.457864   2  0   20.0  0.946462
# 0     LR_MAE  42.638861  41.694531  42.166696   2  0   20.0  0.946462
# 0  LR_MED_AE  45.520869  44.112606  44.816737   2  0   20.0  0.946462
# 0       RMSE  20.076700  19.720586  19.183963   4  0   20.0  0.961144
# 0        MAE  17.344953  17.045621  16.407342   4  0   20.0  0.961144
# 0     MED_AE  16.825497  17.256139  16.191273   4  0   20.0  0.961144
# 0    LR_RMSE  48.728098  47.846162  48.203720   4  0   20.0  0.961144
# 0     LR_MAE  44.214020  42.685339  42.810249   4  0   20.0  0.961144
# 0  LR_MED_AE  48.966816  47.744295  45.685932   4  0   20.0  0.961144
# 0       RMSE  22.610121  29.099684  25.429175   6  0   20.0  0.944444
# 0        MAE  19.424480  25.385345  21.877580   6  0   20.0  0.944444
# 0     MED_AE  19.159274  24.264710  21.337832   6  0   20.0  0.944444
# 0    LR_RMSE  48.276720  47.775743  48.325812   6  0   20.0  0.944444
# 0     LR_MAE  43.440908  41.838794  42.288316   6  0   20.0  0.944444
# 0  LR_MED_AE  47.933254  40.424719  41.761408   6  0   20.0  0.944444
# 0       RMSE  36.409151  22.169047  30.669706   8  0   20.0  0.940913
# 0        MAE  31.303049  18.422009  26.206144   8  0   20.0  0.940913
# 0     MED_AE  31.951922  16.977649  24.992499   8  0   20.0  0.940913
# 0    LR_RMSE  50.010636  47.642938  47.850064   8  0   20.0  0.940913
# 0     LR_MAE  43.178963  42.379746  42.354738   8  0   20.0  0.940913
# 0  LR_MED_AE  39.108943  44.666880  42.970429   8  0   20.0  0.940913
# 0       RMSE  34.275012  30.039849  32.621550  10  0   20.0  0.950094
# 0        MAE  31.261441  26.575782  28.355845  10  0   20.0  0.950094
# 0     MED_AE  33.432781  25.258364  28.335770  10  0   20.0  0.950094
# 0    LR_RMSE  49.658858  48.205820  47.717675  10  0   20.0  0.950094
# 0     LR_MAE  45.100006  42.796841  42.274388  10  0   20.0  0.950094
# 0  LR_MED_AE  48.702834  44.509482  42.823875  10  0   20.0  0.950094
# 0       RMSE  33.646687  37.474978  37.083961  12  0   20.0  0.925350
# 0        MAE  27.049382  32.929331  32.021001  12  0   20.0  0.925350
# 0     MED_AE  22.833948  34.910619  31.529467  12  0   20.0  0.925350
# 0    LR_RMSE  48.712906  51.501293  49.592560  12  0   20.0  0.925350
# 0     LR_MAE  42.313001  45.673635  43.241919  12  0   20.0  0.925350
# 0  LR_MED_AE  39.207947  51.568267  43.111623  12  0   20.0  0.925350
# 0       RMSE  45.188815  37.229455  38.136114  14  0   20.0  0.942351
# 0        MAE  39.043496  32.042701  33.334430  14  0   20.0  0.942351
# 0     MED_AE  40.754710  32.312344  33.985294  14  0   20.0  0.942351
# 0    LR_RMSE  49.300030  47.180226  48.088508  14  0   20.0  0.942351
# 0     LR_MAE  43.686767  42.081511  42.086159  14  0   20.0  0.942351
# 0  LR_MED_AE  43.585867  44.409540  42.259211  14  0   20.0  0.942351
# 0       RMSE  42.188120  48.551124  38.454889  16  0   20.0  0.958956
# 0        MAE  36.887185  42.939397  33.495852  16  0   20.0  0.958956
# 0     MED_AE  37.871166  43.986577  33.409500  16  0   20.0  0.958956
# 0    LR_RMSE  49.359554  61.011030  48.975026  16  0   20.0  0.958956
# 0     LR_MAE  42.611059  53.357558  42.723550  16  0   20.0  0.958956
# 0  LR_MED_AE  39.924644  51.937331  42.173189  16  0   20.0  0.958956
#
#       LR_R2        x_2  ...        x_6        x_7        x_8        x_9  \
# 0  0.057914        NaN  ...        NaN        NaN        NaN        NaN
# 0  0.057914        NaN  ...        NaN        NaN        NaN        NaN
# 0  0.057914        NaN  ...        NaN        NaN        NaN        NaN
# 0  0.057914        NaN  ...        NaN        NaN        NaN        NaN
# 0  0.057914        NaN  ...        NaN        NaN        NaN        NaN
# 0  0.057914        NaN  ...        NaN        NaN        NaN        NaN
# 0  0.075422  19.725398  ...        NaN        NaN        NaN        NaN
# 0  0.075422  16.608155  ...        NaN        NaN        NaN        NaN
# 0  0.075422  16.308734  ...        NaN        NaN        NaN        NaN
# 0  0.075422  47.886720  ...        NaN        NaN        NaN        NaN
# 0  0.075422  43.041748  ...        NaN        NaN        NaN        NaN
# 0  0.075422  47.416093  ...        NaN        NaN        NaN        NaN
# 0  0.123505  25.177117  ...        NaN        NaN        NaN        NaN
# 0  0.123505  21.654425  ...        NaN        NaN        NaN        NaN
# 0  0.123505  22.039955  ...        NaN        NaN        NaN        NaN
# 0  0.123505  49.635464  ...        NaN        NaN        NaN        NaN
# 0  0.123505  44.256868  ...        NaN        NaN        NaN        NaN
# 0  0.123505  51.247697  ...        NaN        NaN        NaN        NaN
# 0  0.086642  29.673427  ...  32.614943  31.745281        NaN        NaN
# 0  0.086642  25.435412  ...  27.867142  27.067772        NaN        NaN
# 0  0.086642  22.936302  ...  28.220915  25.569195        NaN        NaN
# 0  0.086642  47.752131  ...  47.684964  47.766751        NaN        NaN
# 0  0.086642  43.127808  ...  42.251421  42.171485        NaN        NaN
# 0  0.086642  47.008954  ...  45.804120  43.208331        NaN        NaN
# 0  0.096945  32.701675  ...  32.179709  37.005284  35.914248  26.949608
# 0  0.096945  27.446759  ...  27.527498  31.982217  32.080625  22.384630
# 0  0.096945  26.748552  ...  26.915520  31.651374  32.042436  20.824553
# 0  0.096945  47.920962  ...  47.015425  44.826848  47.489361  48.912930
# 0  0.096945  40.750893  ...  41.761109  38.579256  42.880005  43.033596
# 0  0.096945  37.337930  ...  44.089531  37.079463  46.596548  40.407690
# 0  0.197817  39.834286  ...  34.009430  42.770027  43.332617  31.662454
# 0  0.197817  35.640940  ...  31.093725  36.670068  37.121926  27.215357
# 0  0.197817  38.376530  ...  32.839338  37.537031  36.466665  27.048597
# 0  0.197817  49.854139  ...  47.572013  59.622450  51.808319  47.244024
# 0  0.197817  44.453545  ...  42.617923  48.806669  44.510275  41.029893
# 0  0.197817  46.970810  ...  46.464180  50.319238  40.234940  41.360371
# 0  0.136153  38.200729  ...  36.401609  41.611315  35.839292  40.026712
# 0  0.136153  33.872071  ...  31.877173  37.010393  32.231564  35.773349
# 0  0.136153  34.491407  ...  30.555299  38.876286  33.165902  38.328738
# 0  0.136153  46.527494  ...  46.616906  47.610645  48.008365  47.025153
# 0  0.136153  41.521360  ...  41.443417  42.582591  43.280547  42.287493
# 0  0.136153  44.836958  ...  42.119410  45.982117  47.642571  46.626956
# 0  0.142588  41.838182  ...  39.560988  41.995599  38.940461  30.749800
# 0  0.142588  38.018784  ...  34.573449  36.490675  32.953589  26.191991
# 0  0.142588  40.959670  ...  34.704930  33.686743  32.166547  24.980960
# 0  0.142588  47.394041  ...  50.433206  46.934086  50.759414  50.340066
# 0  0.142588  42.671075  ...  44.862384  41.425290  40.822841  43.519266
# 0  0.142588  45.682420  ...  49.266727  44.516789  33.410106  36.835208
#
#         x_10       x_11       x_12       x_13       x_14       x_15
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0  34.581733  41.194008        NaN        NaN        NaN        NaN
# 0  28.958195  37.355151        NaN        NaN        NaN        NaN
# 0  25.206030  41.456900        NaN        NaN        NaN        NaN
# 0  47.029393  47.660555        NaN        NaN        NaN        NaN
# 0  41.170132  43.398417        NaN        NaN        NaN        NaN
# 0  40.404490  44.807945        NaN        NaN        NaN        NaN
# 0  34.529451  37.586257  36.357328  37.790727        NaN        NaN
# 0  29.687142  32.451028  31.690215  32.623512        NaN        NaN
# 0  30.330888  33.449201  32.743650  32.383889        NaN        NaN
# 0  48.641122  47.970990  47.205677  46.882114        NaN        NaN
# 0  42.935884  41.051220  40.682496  40.273969        NaN        NaN
# 0  44.078469  37.550752  40.199322  35.549356        NaN        NaN
# 0  33.580132  36.594914  36.861988  38.935743  35.221987  35.434138
# 0  28.784064  32.355794  32.109500  34.601221  30.923928  30.406555
# 0  25.961562  31.430181  34.082351  35.510381  32.444768  29.126466
# 0  47.387765  45.231762  47.961614  46.705980  47.346942  46.450085
# 0  41.917827  39.591397  42.405711  41.703033  42.117229  40.572237
# 0  44.881773  36.878199  44.516788  43.808668  46.822411  37.654860
#
# [48 rows x 23 columns]

# %%
ax = experiment.plot_model_errors(N, x_col="m", y_col="mu_x_i", figsize=(6, 4))

# %%
ax = experiment.plot_r2(N, x_col="m", figsize=(6, 4))

# %% [markdown]
# # Sinusoidal Target; Variable Number of Sinusoidal Terms
#
# Uniformly distributed $x_i$.
#
# $$
# \begin{align}
# f(X) & = A \cdot X[0, m_1) + b + \left(\sum_{i = m_1}^{m_1 + m_2} {\beta_i} + {\alpha_i}_{\chi[t_i, \infty)}(X[i]) \right); \\
# m_2 & = 4; \\
# m_1 & \ge 1; \\
# s & = 5; \\
# Z & = N(0, \sigma^2).
# \end{align}
# $$

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import impactstudy.experiment as ise

# %% [markdown]
# ## Configuration

# %%
N = 250

# %%
M = list(range(2, 17, 2))

# %%
S = 0

# %%
SIGMA = 20.0

# %% [markdown]
# ## A Single Scenario For Manual Verification.
#
# ### Set Up the Scenario

# %%
experiment0 = ise.ExponentialWithNoiseExperiment(m=M[1], s=S, sigma=SIGMA, n=N)

# %% [markdown]
# ### Generate Impact Charts

# %%
tags, scenario = next(experiment0.scenarios())

# %%
impact_charts = scenario.model_impact_charts(linreg_overlay=True)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits

# %% [markdown]
# ### Generate Metrics

# %%
scenario.model_errors(linreg_errors=True)
# Out:
#       metric        x_0        x_1        x_2        x_3     mu_x_i
# 0       RMSE   5.207029   5.875090   5.824782   4.733340   5.410060
# 0        MAE   2.983863   3.824930   3.735816   3.131941   3.419137
# 0     MED_AE   1.815679   2.715136   2.638706   2.412551   2.395518
# 0    LR_RMSE  21.487416  23.763619  19.023369  19.737090  21.002874
# 0     LR_MAE  14.363910  17.883920  14.363445  13.558454  15.042432
# 0  LR_MED_AE  12.114722  16.157379  13.413130  11.173129  13.214590

# %%
scenario.linreg_r2(), scenario.model_r2()
# Out:
# (0.38115242374380964, 0.9467265404852709)

# %% [markdown]
# ## A Multi-Scenario Experiment

# %%
experiment = ise.ExponentialWithNoiseExperiment(m=M, s=S, sigma=SIGMA, n=N)

# %%
experiment.model_errors(linreg_errors=True)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
#       metric        x_0        x_1     mu_x_i   m  s  sigma     IM_R2  \
# 0       RMSE   3.591164   4.545711   4.068438   2  0   20.0  0.836107
# 0        MAE   2.417454   2.604121   2.510788   2  0   20.0  0.836107
# 0     MED_AE   1.636370   1.640899   1.638634   2  0   20.0  0.836107
# 0    LR_RMSE  17.691876  22.640089  20.165983   2  0   20.0  0.836107
# 0     LR_MAE  13.273392  17.490544  15.381968   2  0   20.0  0.836107
# 0  LR_MED_AE  12.856559  15.729292  14.292925   2  0   20.0  0.836107
# 0       RMSE   5.207029   5.875090   5.410060   4  0   20.0  0.946727
# 0        MAE   2.983863   3.824930   3.419137   4  0   20.0  0.946727
# 0     MED_AE   1.815679   2.715136   2.395518   4  0   20.0  0.946727
# 0    LR_RMSE  21.487416  23.763619  21.002874   4  0   20.0  0.946727
# 0     LR_MAE  14.363910  17.883920  15.042432   4  0   20.0  0.946727
# 0  LR_MED_AE  12.114722  16.157379  13.214590   4  0   20.0  0.946727
# 0       RMSE   8.703446   7.151889   6.921590   6  0   20.0  0.954575
# 0        MAE   5.253028   4.510584   3.943082   6  0   20.0  0.954575
# 0     MED_AE   3.959217   2.901873   2.410073   6  0   20.0  0.954575
# 0    LR_RMSE  18.340683  27.439808  21.821911   6  0   20.0  0.954575
# 0     LR_MAE  11.423328  22.324373  16.246985   6  0   20.0  0.954575
# 0  LR_MED_AE   8.464166  21.150844  14.307514   6  0   20.0  0.954575
# 0       RMSE  10.701989   9.437229   9.643659   8  0   20.0  0.973739
# 0        MAE   5.034157   5.808374   5.233590   8  0   20.0  0.973739
# 0     MED_AE   1.865965   2.397846   2.750169   8  0   20.0  0.973739
# 0    LR_RMSE  22.656521  23.774544  22.140603   8  0   20.0  0.973739
# 0     LR_MAE  15.624133  19.421003  16.240169   8  0   20.0  0.973739
# 0  LR_MED_AE  13.620963  17.649019  14.246393   8  0   20.0  0.973739
# 0       RMSE   9.133288  10.923585  10.405433  10  0   20.0  0.967964
# 0        MAE   6.254902   5.827369   5.890984  10  0   20.0  0.967964
# 0     MED_AE   4.743650   3.157595   3.584043  10  0   20.0  0.967964
# 0    LR_RMSE  19.618516  21.453821  22.249012  10  0   20.0  0.967964
# 0     LR_MAE  14.534553  15.192682  15.710276  10  0   20.0  0.967964
# 0  LR_MED_AE  12.833535  13.569421  13.512456  10  0   20.0  0.967964
# 0       RMSE  10.651636  10.122279  11.024666  12  0   20.0  0.984941
# 0        MAE   5.576647   7.767047   6.701072  12  0   20.0  0.984941
# 0     MED_AE   3.153417   6.558332   4.545677  12  0   20.0  0.984941
# 0    LR_RMSE  20.837108  26.971839  22.372075  12  0   20.0  0.984941
# 0     LR_MAE  13.582030  23.404650  16.416106  12  0   20.0  0.984941
# 0  LR_MED_AE  10.385562  23.834482  14.422098  12  0   20.0  0.984941
# 0       RMSE  10.188837  14.621210  12.346970  14  0   20.0  0.969191
# 0        MAE   6.154520   8.383320   7.201929  14  0   20.0  0.969191
# 0     MED_AE   4.219947   5.779488   4.676482  14  0   20.0  0.969191
# 0    LR_RMSE  21.064448  21.870756  22.042963  14  0   20.0  0.969191
# 0     LR_MAE  15.097449  14.416427  16.040356  14  0   20.0  0.969191
# 0  LR_MED_AE  12.669724  10.773434  14.038012  14  0   20.0  0.969191
# 0       RMSE  10.529565  13.595800  14.476225  16  0   20.0  0.983520
# 0        MAE   5.636848   8.983604   8.601991  16  0   20.0  0.983520
# 0     MED_AE   2.595022   6.331337   5.756959  16  0   20.0  0.983520
# 0    LR_RMSE  24.808300  22.422638  22.048293  16  0   20.0  0.983520
# 0     LR_MAE  16.888302  18.184970  15.775529  16  0   20.0  0.983520
# 0  LR_MED_AE  13.869773  17.402733  13.541141  16  0   20.0  0.983520
#
#       LR_R2        x_2  ...        x_6        x_7        x_8        x_9  \
# 0  0.398179        NaN  ...        NaN        NaN        NaN        NaN
# 0  0.398179        NaN  ...        NaN        NaN        NaN        NaN
# 0  0.398179        NaN  ...        NaN        NaN        NaN        NaN
# 0  0.398179        NaN  ...        NaN        NaN        NaN        NaN
# 0  0.398179        NaN  ...        NaN        NaN        NaN        NaN
# 0  0.398179        NaN  ...        NaN        NaN        NaN        NaN
# 0  0.381152   5.824782  ...        NaN        NaN        NaN        NaN
# 0  0.381152   3.735816  ...        NaN        NaN        NaN        NaN
# 0  0.381152   2.638706  ...        NaN        NaN        NaN        NaN
# 0  0.381152  19.023369  ...        NaN        NaN        NaN        NaN
# 0  0.381152  14.363445  ...        NaN        NaN        NaN        NaN
# 0  0.381152  13.413130  ...        NaN        NaN        NaN        NaN
# 0  0.457825   5.483840  ...        NaN        NaN        NaN        NaN
# 0  0.457825   2.725240  ...        NaN        NaN        NaN        NaN
# 0  0.457825   1.368706  ...        NaN        NaN        NaN        NaN
# 0  0.457825  23.112548  ...        NaN        NaN        NaN        NaN
# 0  0.457825  16.538377  ...        NaN        NaN        NaN        NaN
# 0  0.457825  14.101997  ...        NaN        NaN        NaN        NaN
# 0  0.507414   7.453974  ...   9.851885   9.219249        NaN        NaN
# 0  0.507414   3.594941  ...   5.518603   4.770374        NaN        NaN
# 0  0.507414   1.832104  ...   3.217535   2.330822        NaN        NaN
# 0  0.507414  20.297446  ...  22.067040  24.166591        NaN        NaN
# 0  0.507414  15.486164  ...  15.990252  19.530202        NaN        NaN
# 0  0.507414  14.180951  ...  14.427585  18.964353        NaN        NaN
# 0  0.434552  13.592150  ...  11.023841   7.099390  10.855872  12.788698
# 0  0.434552   7.198596  ...   6.175650   4.431548   5.834887   7.177091
# 0  0.434552   4.571265  ...   4.254339   2.923021   2.764317   3.692738
# 0  0.434552  22.628777  ...  20.842609  21.647866  21.634050  23.209984
# 0  0.434552  12.738135  ...  12.533263  17.244261  15.633395  16.866876
# 0  0.434552   9.389337  ...   9.402429  16.506939  13.347372  13.836002
# 0  0.531785  10.120724  ...  13.928246  10.956295  12.584349  11.180056
# 0  0.531785   6.199473  ...   7.823256   7.116988   7.392361   7.368966
# 0  0.531785   3.920962  ...   4.664420   5.386087   5.433466   5.037158
# 0  0.531785  22.575213  ...  19.954053  23.439437  23.089444  22.813534
# 0  0.531785  14.674935  ...  13.837854  15.885136  14.044208  17.594502
# 0  0.531785  10.832599  ...  12.098091  12.668374   8.914221  15.828997
# 0  0.500796  13.592933  ...  11.066311   9.365876  13.955527  15.354192
# 0  0.500796   8.122540  ...   7.515821   5.450142   7.958427   8.613730
# 0  0.500796   5.106316  ...   5.387730   3.283007   5.304945   5.829170
# 0  0.500796  23.900653  ...  20.959324  25.831798  23.753841  21.289349
# 0  0.500796  15.550028  ...  13.828456  21.541366  14.157716  14.079739
# 0  0.500796  11.608627  ...  10.307309  21.713551  10.677417  10.620026
# 0  0.461616  15.911333  ...  11.873761  11.096717  12.457416  15.826402
# 0  0.461616   8.430195  ...   7.017240   7.279170   8.090252  11.088965
# 0  0.461616   4.184937  ...   4.728206   5.462620   6.066594   8.986490
# 0  0.461616  20.565775  ...  21.870299  24.063609  18.695957  24.278886
# 0  0.461616  16.313828  ...  15.768600  17.645733  11.919880  20.529636
# 0  0.461616  15.516407  ...  14.067866  14.769692   9.388283  20.638531
#
#         x_10       x_11       x_12       x_13       x_14       x_15
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 0  11.397459   8.296822        NaN        NaN        NaN        NaN
# 0   6.226072   5.756445        NaN        NaN        NaN        NaN
# 0   3.771022   4.644935        NaN        NaN        NaN        NaN
# 0  24.830547  18.555150        NaN        NaN        NaN        NaN
# 0  20.185233  14.349621        NaN        NaN        NaN        NaN
# 0  19.678608  13.092967        NaN        NaN        NaN        NaN
# 0   8.951155  11.136106  14.934113  10.281400        NaN        NaN
# 0   4.432121   6.322531   8.719737   5.209039        NaN        NaN
# 0   2.203367   4.184240   5.553686   2.177025        NaN        NaN
# 0  23.016208  22.285173  19.691399  21.244894        NaN        NaN
# 0  17.936066  17.588120  14.411875  16.242680        NaN        NaN
# 0  16.535858  16.242958  13.509743  14.396965        NaN        NaN
# 0  13.957713  18.607645  16.546910  13.565323  15.652934  15.952478
# 0   7.646297  11.796720  10.096358   8.139759   8.609518   8.977605
# 0   5.098509   8.526055   6.807022   5.228716   5.247085   5.713246
# 0  19.616704  23.407473  22.327976  25.707278  23.001966  21.548331
# 0  12.495667  14.428984  15.267170  20.101257  15.167793  16.107525
# 0   9.092874   9.974716  12.099735  18.599258  11.743849  14.340533
#
# [48 rows x 23 columns]

# %%
ax = experiment.plot_model_errors(x_col="m", y_col="mu_x_i", figsize=(6, 4))

# %%
ax = experiment.plot_r2(x_col="m", figsize=(6, 4))

# %% [markdown]
# # Quadratic Target; Variable Number of Quadratic Terms
#
# Uniformly distributed $x_i$.
#
# $$
# \begin{align}
# f(X) & = A \cdot X[0, m_1) + b + \left(\sum_{i = m_1}^{m_1 + m_2} {\beta_i} + {\alpha_i}_{\chi[t_i, \infty)}(X[i]) \right); \\
# m_2 & = 4; \\
# m_1 & \ge 1; \\
# s & = 5; \\
# Z & = N(0, \sigma^2).
# \end{align}
# $$

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import impactstudy.experiment as ise

# %% [markdown]
# ## Configuration

# %%
N = 250

# %%
M = list(range(2, 17, 2))

# %%
S = 0

# %%
SIGMA = 20.0

# %% [markdown]
# ## A Single Scenario For Manual Verification.
#
# ### Set Up the Scenario

# %%
experiment0 = ise.QuadraticWithNoiseExperiment(
    m=M[1], s=S, sigma=SIGMA
)

# %% [markdown]
# ### Generate Impact Charts

# %%
tags, scenario = next(experiment0.scenarios())

# %%
impact_charts = scenario.model_impact_charts(N, linreg_overlay=True)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits

# %% [markdown]
# ### Generate Metrics

# %%
scenario.model_errors(N, linreg_errors=True)
# Out:
#       metric       x_0       x_1       x_2       x_3    mu_x_i
# 0       RMSE  3.631062  2.658306  2.674769  3.932230  3.224092
# 0        MAE  2.840945  2.246807  2.263637  3.312445  2.665959
# 0     MED_AE  2.536178  2.125180  2.066662  3.312349  2.510092
# 0    LR_RMSE  7.386119  7.654294  7.310348  7.230762  7.395381
# 0     LR_MAE  6.198636  6.654281  6.119611  6.269579  6.310527
# 0  LR_MED_AE  6.072358  6.617205  6.070284  6.238717  6.249641

# %%
scenario.linreg_r2(N), scenario.model_r2(N)
# Out:
# (0.005461478013909393, 0.4250140492439568)

# %% [markdown]
# ## A Multi-Scenario Experiment

# %%
experiment = ise.QuadraticWithNoiseExperiment(
    m=M, s=S, sigma=SIGMA
)

# %%
experiment.model_errors(N, linreg_errors=True)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
#       metric       x_0       x_1    mu_x_i   m  s  sigma     IM_R2     LR_R2  \
# 0       RMSE  3.967668  3.631437  3.799553   2  0   20.0  0.281172  0.000797
# 0        MAE  3.212912  3.035265  3.124089   2  0   20.0  0.281172  0.000797
# 0     MED_AE  2.970090  2.994225  2.982158   2  0   20.0  0.281172  0.000797
# 0    LR_RMSE  7.620113  7.783752  7.701932   2  0   20.0  0.281172  0.000797
# 0     LR_MAE  6.480908  6.840845  6.660877   2  0   20.0  0.281172  0.000797
# 0  LR_MED_AE  6.608546  6.672899  6.640722   2  0   20.0  0.281172  0.000797
# 0       RMSE  3.631062  2.658306  3.224092   4  0   20.0  0.425014  0.005461
# 0        MAE  2.840945  2.246807  2.665959   4  0   20.0  0.425014  0.005461
# 0     MED_AE  2.536178  2.125180  2.510092   4  0   20.0  0.425014  0.005461
# 0    LR_RMSE  7.386119  7.654294  7.395381   4  0   20.0  0.425014  0.005461
# 0     LR_MAE  6.198636  6.654281  6.310527   4  0   20.0  0.425014  0.005461
# 0  LR_MED_AE  6.072358  6.617205  6.249641   4  0   20.0  0.425014  0.005461
# 0       RMSE  4.705327  4.354736  4.007055   6  0   20.0  0.532997  0.028217
# 0        MAE  3.990536  3.619631  3.300320   6  0   20.0  0.532997  0.028217
# 0     MED_AE  3.404023  3.227471  2.994411   6  0   20.0  0.532997  0.028217
# 0    LR_RMSE  7.462437  8.087358  7.566615   6  0   20.0  0.532997  0.028217
# 0     LR_MAE  6.182748  7.054026  6.505788   6  0   20.0  0.532997  0.028217
# 0  LR_MED_AE  5.643919  7.232232  6.415835   6  0   20.0  0.532997  0.028217
# 0       RMSE  4.054272  3.505938  3.745615   8  0   20.0  0.889923  0.029788
# 0        MAE  3.027112  2.712566  2.943558   8  0   20.0  0.889923  0.029788
# 0     MED_AE  2.035128  2.054550  2.487459   8  0   20.0  0.889923  0.029788
# 0    LR_RMSE  7.664657  7.538832  7.491628   8  0   20.0  0.889923  0.029788
# 0     LR_MAE  6.286953  6.425089  6.348312   8  0   20.0  0.889923  0.029788
# 0  LR_MED_AE  5.914725  6.068910  6.199251   8  0   20.0  0.889923  0.029788
# 0       RMSE  5.099628  3.074433  3.965594  10  0   20.0  0.944353  0.027383
# 0        MAE  4.386690  2.372206  3.118865  10  0   20.0  0.944353  0.027383
# 0     MED_AE  3.988042  1.911051  2.657049  10  0   20.0  0.944353  0.027383
# 0    LR_RMSE  7.096101  7.708671  7.566223  10  0   20.0  0.944353  0.027383
# 0     LR_MAE  6.060762  6.649754  6.454026  10  0   20.0  0.944353  0.027383
# 0  LR_MED_AE  6.023755  6.421886  6.525361  10  0   20.0  0.944353  0.027383
# 0       RMSE  4.706095  2.818106  4.564813  12  0   20.0  0.898419  0.069692
# 0        MAE  3.539406  2.244344  3.721556  12  0   20.0  0.898419  0.069692
# 0     MED_AE  2.748421  1.931371  3.384466  12  0   20.0  0.898419  0.069692
# 0    LR_RMSE  7.828632  8.006798  7.927302  12  0   20.0  0.898419  0.069692
# 0     LR_MAE  6.582575  7.017943  6.705364  12  0   20.0  0.898419  0.069692
# 0  LR_MED_AE  6.368444  7.359824  6.643344  12  0   20.0  0.898419  0.069692
# 0       RMSE  3.528140  6.197112  5.155979  14  0   20.0  0.891249  0.106161
# 0        MAE  2.906333  5.293145  4.229098  14  0   20.0  0.891249  0.106161
# 0     MED_AE  2.608372  5.085333  3.866854  14  0   20.0  0.891249  0.106161
# 0    LR_RMSE  7.312260  7.363645  7.859575  14  0   20.0  0.891249  0.106161
# 0     LR_MAE  6.045001  6.297994  6.651774  14  0   20.0  0.891249  0.106161
# 0  LR_MED_AE  5.714211  5.959968  6.530126  14  0   20.0  0.891249  0.106161
# 0       RMSE  3.265081  5.006717  4.871438  16  0   20.0  0.953835  0.086879
# 0        MAE  2.534321  3.984132  3.989232  16  0   20.0  0.953835  0.086879
# 0     MED_AE  2.127137  3.697233  3.652552  16  0   20.0  0.953835  0.086879
# 0    LR_RMSE  7.579081  7.249069  7.791773  16  0   20.0  0.953835  0.086879
# 0     LR_MAE  6.414911  6.257738  6.585770  16  0   20.0  0.953835  0.086879
# 0  LR_MED_AE  6.275779  6.323120  6.526583  16  0   20.0  0.953835  0.086879
#
#         x_2  ...       x_6       x_7       x_8       x_9      x_10      x_11  \
# 0       NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  2.674769  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  2.263637  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  2.066662  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  7.310348  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  6.119611  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  6.070284  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  3.211879  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  2.731543  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  2.578282  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  7.506057  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  6.516685  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  6.580587  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  2.741061  ...  3.366715  4.213591       NaN       NaN       NaN       NaN
# 0  2.219918  ...  2.835059  3.331127       NaN       NaN       NaN       NaN
# 0  1.979042  ...  2.595327  2.978767       NaN       NaN       NaN       NaN
# 0  7.448562  ...  6.894127  7.711163       NaN       NaN       NaN       NaN
# 0  6.485181  ...  5.629668  6.657481       NaN       NaN       NaN       NaN
# 0  6.620173  ...  5.404024  6.599095       NaN       NaN       NaN       NaN
# 0  5.547323  ...  4.462627  2.724319  3.188696  4.518225       NaN       NaN
# 0  4.086931  ...  3.768722  2.239304  2.487100  3.308318       NaN       NaN
# 0  3.391174  ...  3.632084  2.013299  2.075642  2.352847       NaN       NaN
# 0  7.796526  ...  7.573198  7.918161  7.457316  7.311063       NaN       NaN
# 0  6.501090  ...  6.362466  6.965186  6.343781  6.257337       NaN       NaN
# 0  6.409981  ...  6.466144  7.506718  6.174332  6.260088       NaN       NaN
# 0  4.701143  ...  4.549427  5.879040  4.550281  5.455973  4.214908  4.991809
# 0  4.039064  ...  3.428762  5.078451  3.844483  4.597556  3.258850  4.103002
# 0  4.105506  ...  2.689336  5.336223  3.762943  4.295513  2.611888  4.096494
# 0  8.281463  ...  7.450652  8.566416  7.984177  7.766431  8.741489  7.610464
# 0  6.848495  ...  6.261268  7.113255  6.677857  6.715277  7.282186  6.504429
# 0  6.687686  ...  6.134566  7.010411  6.451611  6.623213  7.014133  6.870459
# 0  5.462808  ...  4.040869  5.190688  5.377806  6.411635  3.709839  5.036680
# 0  4.310413  ...  3.455530  4.324849  4.324985  5.265512  2.653447  3.845279
# 0  3.423252  ...  3.352818  3.915823  4.001225  5.099431  2.135308  3.035818
# 0  9.502124  ...  7.709558  8.149559  8.719164  7.550346  7.441243  8.931136
# 0  7.808601  ...  6.697722  7.007276  7.075231  6.490679  6.222159  7.397616
# 0  7.363401  ...  6.521596  7.174271  6.655513  6.898820  6.066182  7.465987
# 0  5.260418  ...  3.490164  5.635763  2.754533  5.547443  5.009674  6.991301
# 0  4.294197  ...  2.871011  4.787007  2.258012  4.623919  4.126485  5.904589
# 0  3.830850  ...  2.578522  4.417611  1.973621  4.472942  3.846414  5.508979
# 0  7.654881  ...  6.997215  7.819932  7.355374  9.180133  8.535723  8.091705
# 0  6.612116  ...  5.858960  6.719112  6.427845  7.161559  7.111765  6.620203
# 0  6.638535  ...  5.953899  6.512698  6.677664  6.486663  6.899085  6.616598
#
#        x_12      x_13      x_14      x_15
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0  5.876824  3.585870       NaN       NaN
# 0  4.902059  2.868589       NaN       NaN
# 0  4.429316  2.643455       NaN       NaN
# 0  7.613892  7.588454       NaN       NaN
# 0  6.423711  6.601425       NaN       NaN
# 0  6.248751  6.690814       NaN       NaN
# 0  5.214602  5.412383  4.326180  5.709254
# 0  4.298632  4.709065  3.267384  4.809326
# 0  3.825834  4.642382  2.504937  4.618074
# 0  8.197983  8.269580  7.380244  7.686404
# 0  6.928883  7.373150  6.055612  6.523369
# 0  6.645173  7.567794  5.669376  6.560516
#
# [48 rows x 23 columns]

# %%
ax = experiment.plot_model_errors(N, x_col="m", y_col="mu_x_i", figsize=(6, 4))

# %%
ax = experiment.plot_r2(N, x_col="m", figsize=(6, 4))

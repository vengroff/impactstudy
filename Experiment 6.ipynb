# %% [markdown]
# # Quadratic Target; Variable Number of Quadratic Terms
#
# Uniformly distributed $x_i$.
#
# $$
# \begin{align}
# f(X) & = A \cdot X[0, m_1) + b + \left(\sum_{i = m_1}^{m_1 + m_2} {\beta_i} + {\alpha_i}_{\chi[t_i, \infty)}(X[i]) \right); \\
# m_2 & = 4; \\
# m_1 & \ge 1; \\
# s & = 5; \\
# Z & = N(0, \sigma^2).
# \end{align}
# $$

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import impactstudy.experiment as ise

# %% [markdown]
# ## Configuration

# %%
N = 250

# %%
M = list(range(2, 17, 2))

# %%
S = 0

# %%
SIGMA = 20.0

# %% [markdown]
# ## A Single Scenario For Manual Verification.
#
# ### Set Up the Scenario

# %%
experiment0 = ise.QuadraticWithNoiseExperiment(m=M[1], s=S, sigma=SIGMA, n=N)

# %% [markdown]
# ### Generate Impact Charts

# %%
tags, scenario = next(experiment0.scenarios())

# %%
impact_charts = scenario.model_impact_charts(linreg_overlay=True)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits

# %% [markdown]
# ### Generate Metrics

# %%
scenario.model_errors(linreg_errors=True)
# Out:
#       metric       x_0       x_1       x_2       x_3    mu_x_i
# 0       RMSE  2.662575  3.350819  3.733048  2.273216  3.004915
# 0        MAE  1.742335  2.351547  2.234926  1.443423  1.943058
# 0     MED_AE  1.338633  2.101761  1.935324  1.021904  1.599406
# 0    LR_RMSE  5.528877  6.140314  6.196420  5.097811  5.740855
# 0     LR_MAE  4.081008  4.307609  4.051649  3.655300  4.023892
# 0  LR_MED_AE  3.656829  3.626949  3.352303  3.302539  3.484655

# %%
scenario.linreg_r2(), scenario.model_r2()
# Out:
# (0.017684506152102264, 0.40609095190045874)

# %% [markdown]
# ## A Multi-Scenario Experiment

# %%
experiment = ise.QuadraticWithNoiseExperiment(m=M, s=S, sigma=SIGMA, n=N)

# %%
experiment.model_errors(linreg_errors=True)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
#       metric       x_0       x_1    mu_x_i   m  s  sigma     IM_R2     LR_R2  \
# 0       RMSE  3.880629  1.966121  2.923375   2  0   20.0  0.268521  0.000809
# 0        MAE  2.384229  1.591954  1.988091   2  0   20.0  0.268521  0.000809
# 0     MED_AE  1.798204  1.497274  1.647739   2  0   20.0  0.268521  0.000809
# 0    LR_RMSE  5.978427  5.947152  5.962789   2  0   20.0  0.268521  0.000809
# 0     LR_MAE  3.990756  4.229310  4.110033   2  0   20.0  0.268521  0.000809
# 0  LR_MED_AE  3.347848  3.584357  3.466103   2  0   20.0  0.268521  0.000809
# 0       RMSE  2.662575  3.350819  3.004915   4  0   20.0  0.406091  0.017685
# 0        MAE  1.742335  2.351547  1.943058   4  0   20.0  0.406091  0.017685
# 0     MED_AE  1.338633  2.101761  1.599406   4  0   20.0  0.406091  0.017685
# 0    LR_RMSE  5.528877  6.140314  5.740855   4  0   20.0  0.406091  0.017685
# 0     LR_MAE  4.081008  4.307609  4.023892   4  0   20.0  0.406091  0.017685
# 0  LR_MED_AE  3.656829  3.626949  3.484655   4  0   20.0  0.406091  0.017685
# 0       RMSE  3.279063  2.809883  3.547454   6  0   20.0  0.542692  0.049618
# 0        MAE  2.258117  1.702528  2.238249   6  0   20.0  0.542692  0.049618
# 0     MED_AE  1.858552  0.888760  1.582826   6  0   20.0  0.542692  0.049618
# 0    LR_RMSE  5.523285  5.315197  5.798083   6  0   20.0  0.542692  0.049618
# 0     LR_MAE  3.961999  3.695645  4.072947   6  0   20.0  0.542692  0.049618
# 0  LR_MED_AE  3.493984  3.220999  3.492417   6  0   20.0  0.542692  0.049618
# 0       RMSE  3.391345  4.080055  3.867181   8  0   20.0  0.567465  0.037487
# 0        MAE  2.427180  2.808234  2.518825   8  0   20.0  0.567465  0.037487
# 0     MED_AE  2.122680  2.264677  2.009801   8  0   20.0  0.567465  0.037487
# 0    LR_RMSE  5.291802  5.551102  6.057665   8  0   20.0  0.567465  0.037487
# 0     LR_MAE  3.896204  3.871038  4.136319   8  0   20.0  0.567465  0.037487
# 0  LR_MED_AE  3.420000  3.281779  3.524462   8  0   20.0  0.567465  0.037487
# 0       RMSE  3.969785  3.862319  3.984613  10  0   20.0  0.614365  0.029698
# 0        MAE  2.430194  2.318630  2.470219  10  0   20.0  0.614365  0.029698
# 0     MED_AE  1.735024  1.667262  1.851911  10  0   20.0  0.614365  0.029698
# 0    LR_RMSE  5.792926  6.436273  5.796686  10  0   20.0  0.614365  0.029698
# 0     LR_MAE  4.009042  4.561863  4.025199  10  0   20.0  0.614365  0.029698
# 0  LR_MED_AE  3.394327  4.056061  3.430282  10  0   20.0  0.614365  0.029698
# 0       RMSE  4.105882  4.161735  4.170268  12  0   20.0  0.860670  0.044789
# 0        MAE  2.655516  3.036611  2.602509  12  0   20.0  0.860670  0.044789
# 0     MED_AE  2.004492  2.424261  1.848110  12  0   20.0  0.860670  0.044789
# 0    LR_RMSE  5.974696  5.512934  5.874523  12  0   20.0  0.860670  0.044789
# 0     LR_MAE  3.874560  3.860196  4.005547  12  0   20.0  0.860670  0.044789
# 0  LR_MED_AE  3.319495  3.376342  3.440710  12  0   20.0  0.860670  0.044789
# 0       RMSE  4.052714  4.765169  4.558655  14  0   20.0  0.816494  0.078108
# 0        MAE  2.730219  2.794466  2.949947  14  0   20.0  0.816494  0.078108
# 0     MED_AE  2.015978  1.572970  2.161932  14  0   20.0  0.816494  0.078108
# 0    LR_RMSE  6.252853  6.700628  6.086251  14  0   20.0  0.816494  0.078108
# 0     LR_MAE  4.377859  4.455707  4.130646  14  0   20.0  0.816494  0.078108
# 0  LR_MED_AE  3.776057  3.550594  3.516467  14  0   20.0  0.816494  0.078108
# 0       RMSE  5.087241  4.993523  4.361863  16  0   20.0  0.586520  0.048860
# 0        MAE  3.680989  3.725276  2.824229  16  0   20.0  0.586520  0.048860
# 0     MED_AE  3.231970  3.199318  2.288807  16  0   20.0  0.586520  0.048860
# 0    LR_RMSE  5.405989  5.396613  5.827801  16  0   20.0  0.586520  0.048860
# 0     LR_MAE  3.898658  3.883365  4.037122  16  0   20.0  0.586520  0.048860
# 0  LR_MED_AE  3.433936  3.326661  3.437038  16  0   20.0  0.586520  0.048860
#
#         x_2  ...       x_6       x_7       x_8       x_9      x_10      x_11  \
# 0       NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0       NaN  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  3.733048  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  2.234926  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  1.935324  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  6.196420  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  4.051649  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  3.352303  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  4.190266  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  2.549491  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  1.871406  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  7.093766  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  4.796450  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  3.865702  ...       NaN       NaN       NaN       NaN       NaN       NaN
# 0  4.527138  ...  3.938450  4.336527       NaN       NaN       NaN       NaN
# 0  2.812334  ...  2.591960  2.844267       NaN       NaN       NaN       NaN
# 0  1.695986  ...  2.155056  2.482151       NaN       NaN       NaN       NaN
# 0  6.746422  ...  5.375523  6.046397       NaN       NaN       NaN       NaN
# 0  4.453236  ...  3.561798  4.183095       NaN       NaN       NaN       NaN
# 0  3.719169  ...  3.091377  3.530064       NaN       NaN       NaN       NaN
# 0  4.439774  ...  3.962250  3.426493  3.715085  4.430310       NaN       NaN
# 0  2.471689  ...  2.552284  2.230976  2.032218  2.816543       NaN       NaN
# 0  1.892505  ...  1.850697  1.624534  1.354534  2.227699       NaN       NaN
# 0  6.011624  ...  6.198261  4.865842  5.857621  6.122624       NaN       NaN
# 0  3.932203  ...  4.268894  3.538540  3.892947  4.266371       NaN       NaN
# 0  3.265889  ...  3.610201  2.936571  3.364685  3.566578       NaN       NaN
# 0  4.392335  ...  3.280135  4.553123  5.099103  4.439432  3.698510  4.002196
# 0  2.499742  ...  2.185811  2.901638  3.496653  2.784657  1.904268  2.641669
# 0  1.690576  ...  1.566140  2.046619  2.814378  1.901483  1.244516  1.627095
# 0  6.441355  ...  5.532405  5.329635  5.848131  6.914579  5.333452  5.645955
# 0  4.149813  ...  4.045062  3.620723  3.814712  4.686630  3.506396  4.123493
# 0  3.366882  ...  3.614909  3.136548  3.201506  3.973988  2.953950  3.501537
# 0  3.007305  ...  3.809928  5.043323  4.806171  3.637275  5.542990  3.885883
# 0  1.834852  ...  2.043874  3.106608  3.526947  2.405232  3.741611  2.929905
# 0  1.343075  ...  1.217504  1.885337  2.945593  1.943833  3.120300  2.715550
# 0  4.721470  ...  5.572677  6.693786  5.073862  5.749676  6.529480  6.186615
# 0  3.209791  ...  3.716146  4.133842  3.677695  3.713221  4.486057  4.488039
# 0  2.704639  ...  3.070099  3.258880  3.180547  3.246154  3.999493  3.981498
# 0  5.189573  ...  5.417048  4.869679  3.564693  4.913741  3.504091  6.021528
# 0  2.999595  ...  3.535901  3.510139  2.542193  3.133782  1.856887  3.803272
# 0  2.448697  ...  2.948147  3.057983  1.970033  2.421114  1.236250  3.271232
# 0  6.610468  ...  5.995771  5.305850  7.076424  6.069963  5.895744  6.401915
# 0  4.345743  ...  4.092963  3.780758  5.229271  4.124402  4.052110  4.189752
# 0  3.613393  ...  3.505310  3.304889  4.729246  3.542485  3.364368  3.701100
#
#        x_12      x_13      x_14      x_15
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0       NaN       NaN       NaN       NaN
# 0  5.363500  4.483980       NaN       NaN
# 0  2.971684  2.883287       NaN       NaN
# 0  1.502875  1.720823       NaN       NaN
# 0  6.521868  5.836240       NaN       NaN
# 0  3.856430  4.373815       NaN       NaN
# 0  3.180810  3.896962       NaN       NaN
# 0  3.015544  2.833955  2.848869  4.618231
# 0  1.954751  1.848313  1.795149  2.800522
# 0  1.575871  1.544760  1.229089  2.079332
# 0  5.745585  6.068632  4.350399  6.113701
# 0  3.975396  4.270826  3.207034  4.168908
# 0  3.361368  3.606168  2.858472  3.293906
#
# [48 rows x 23 columns]

# %%
ax = experiment.plot_model_errors(x_col="m", y_col="mu_x_i", figsize=(6, 4))

# %%
ax = experiment.plot_r2(x_col="m", figsize=(6, 4))
